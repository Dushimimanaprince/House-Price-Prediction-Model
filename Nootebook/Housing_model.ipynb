# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[['bedrooms','bathrooms','stories','parking']]
y=df['price']

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm= LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 221177.8544539 , 1386920.62824564,  463424.53047652,
#         649360.16824074])

# %%
predictions= lm.predict(X_test)

# %%
predictions
# Out:
# array([6331476.93433886, 5924363.44212075, 3389415.89846817,
#        4074018.28339859, 3610593.75292206, 3610593.75292206,
#        4909314.08940354, 5682116.76609813, 4038776.0667089 ,
#        3610593.75292206, 9294606.79177829, 3389415.89846817,
#        3389415.89846817, 4074018.28339859, 4074018.28339859,
#        6847859.53988987, 3852840.42894469, 4723378.45163932,
#        4723378.45163932, 3389415.89846817, 5000867.34435163,
#        3610593.75292206, 3389415.89846817, 4723378.45163932,
#        5558674.25764427, 6759659.2481257 , 3389415.89846817,
#        5460938.91164423, 5372738.61988006, 3852840.42894469,
#        5460938.91164423, 4723378.45163932, 5924363.44212075,
#        4074018.28339859, 4295196.13785249, 6110299.07988496,
#        5372738.61988006, 4295196.13785249, 3610593.75292206,
#        5682116.76609813, 4909314.08940354, 3389415.89846817,
#        5924363.44212075, 4723378.45163932, 3389415.89846817,
# ...

# %%
sns.scatterplot(x=predictions,y=y_test)
# Out:
# <Axes: ylabel='price'>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import math

# %%
print("The Absolute Error: ",mean_absolute_error(y_test,predictions))
print("The Squared Error: ",mean_squared_error(y_test,predictions))
print("The RMSE: ",math.sqrt(mean_squared_error(y_test,predictions)))
# Out:
# The Absolute Error:  1185619.4341258558
# The Squared Error:  2476791101195.4585
# The RMSE:  1573782.4186320861

# %%
df['price'].describe()
# Out:
# count    5.450000e+02
# mean     4.766729e+06
# std      1.870440e+06
# min      1.750000e+06
# 25%      3.430000e+06
# 50%      4.340000e+06
# 75%      5.740000e+06
# max      1.330000e+07
# Name: price, dtype: float64

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df['mainroad_bin'] = df['mainroad'].map({'yes': 1, 'no': 0})

# %%
df['guestroom_bin']= df['guestroom'].map({'yes':1,'no':0})
df['basement_bin']= df['basement'].map({'yes':1,'no':0})
df['hot_bin']= df['hotwaterheating'].map({'yes':1,'no':0})
df['aircond_bin']= df['airconditioning'].map({'yes':1,'no':0})

# %%
a= df[[]]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
A=df[['area','bedrooms','bathrooms','stories','parking','mainroad_bin','guestroom_bin','basement_bin','hot_bin','aircond_bin']]
b=df['price']

# %%
A_train,A_test,b_train,b_test= train_test_split(A,y,test_size=0.3,random_state=42)

# %%
lms= LinearRegression()

# %%
lms.fit(A_train,b_train)
# Out:
# LinearRegression()

# %%
lms.coef_
# Out:
# array([2.70114378e+02, 9.80134091e+04, 1.09465653e+06, 4.38507871e+05,
#        3.30116965e+05, 5.53242485e+05, 3.40245946e+05, 6.10730935e+05,
#        6.13353662e+05, 6.98008075e+05])

# %%
predict= lms.predict(A_test)

# %%
predict
# Out:
# array([5168906.03448034, 6217011.87038639, 3198824.08190017,
#        4605808.37688392, 3365863.44668403, 3365863.44668403,
#        5227615.64217588, 6202272.41304869, 3275362.67458246,
#        2395502.36652865, 8979149.10309743, 3198824.08190017,
#        3106320.82281192, 3260803.09811439, 4231164.17826978,
#        5810774.73002616, 3560911.19103291, 5097755.56409627,
#        4723111.36548214, 3198824.08190017, 5329982.5951494 ,
#        5301887.3758295 , 3198824.08190017, 5278063.85110745,
#        5344918.63077411, 6464174.93706422, 4256990.18997849,
#        6035233.04826482, 6092916.37376163, 3560911.19103291,
#        6358138.38370665, 4219897.74302913, 6771964.3560117 ,
#        3727950.55581678, 3894989.92060064, 6346871.948466  ,
#        5770011.03831981, 5276061.36412079, 3273360.18759579,
#        5144106.30497037, 4349757.82110874, 4076681.90296731,
#        6217011.87038639, 4219897.74302913, 3198824.08190017,
# ...

# %%
print("The Absolute Error: ",mean_absolute_error(b_test,predict))
print("The Squared Error: ",mean_squared_error(b_test,predict))
print("The RMSE: ",math.sqrt(mean_squared_error(b_test,predict)))
# Out:
# The Absolute Error:  956725.7281477173
# The Squared Error:  1688349072165.002
# The RMSE:  1299364.8726069988

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
newhouse=[[7255,4,2,1,2,1,0,1,0,1]]

# %%
pred= lms.predict(newhouse)
print("House Price", pred)
# Out:
# House Price [7189976.1874575]
# C:\Users\CTRL-SHIFT Ltd\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
